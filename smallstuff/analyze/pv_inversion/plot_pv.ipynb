# %%
# %pylab inline
from inversion_tools import qgpv_invert
import warnings
warnings.filterwarnings("ignore")
import matplotlib.transforms as mtransforms
nx = 2000
ny = 1800
nz = 100
hres = 4
zl = 20
xl, yl, x, y, xg, yg, dz, zp, facz = qgpv_invert.cartesian_mesh(nx, ny, nz, hres, zl)

te_48 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/te_48h.npy')
te_72 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/te_72h.npy')
te_96 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/te_96h.npy')
dtdz = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/dt_r_dz.npy')
n = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/n_r.npy')

# %%
dte_up_adj48 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h/dte_up.npy')
dte_low_adj48 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h/dte_low.npy')

dte_up_adj72 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h/dte_up.npy')
dte_low_adj72 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h/dte_low.npy')

dte_up_adj96 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h/dte_up.npy')
dte_low_adj96 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h/dte_low.npy')

dte_up_wave48 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h/dte_up.npy')
dte_low_wave48 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h/dte_low.npy')

dte_up_wave72 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h/dte_up.npy')
dte_low_wave72 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h/dte_low.npy')

dte_up_wave96 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h/dte_up.npy')
dte_low_wave96 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h/dte_low.npy')

dte_up_adj48_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h_10/dte_up.npy')
dte_low_adj48_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h_10/dte_low.npy')

dte_up_adj72_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h_10/dte_up.npy')
dte_low_adj72_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h_10/dte_low.npy')

dte_up_adj96_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h_10/dte_up.npy')
dte_low_adj96_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h_10/dte_low.npy')

dte_up_wave48_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h_10/dte_up.npy')
dte_low_wave48_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h_10/dte_low.npy')

dte_up_wave72_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h_10/dte_up.npy')
dte_low_wave72_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h_10/dte_low.npy')

dte_up_wave96_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h_10/dte_up.npy')
dte_low_wave96_10 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h_10/dte_low.npy')

dte_up_adj48_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h_100/dte_up.npy')
dte_low_adj48_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_48h_100/dte_low.npy')

dte_up_adj72_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h_100/dte_up.npy')
dte_low_adj72_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_72h_100/dte_low.npy')

dte_up_adj96_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h_100/dte_up.npy')
dte_low_adj96_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/adj_96h_100/dte_low.npy')

dte_up_wave48_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h_100/dte_up.npy')
dte_low_wave48_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_48h_100/dte_low.npy')

dte_up_wave72_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h_100/dte_up.npy')
dte_low_wave72_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_72h_100/dte_low.npy')

dte_up_wave96_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h_100/dte_up.npy')
dte_low_wave96_100 = np.load('/p/work1/lloveras/adj_4km/processed/pv_inversion/wave_96h_100/dte_low.npy')

# %%
dtenorm_up_adj48 = dte_up_adj48/te_48
dtenorm_low_adj48 = dte_low_adj48/te_48

dtenorm_up_adj72 = dte_up_adj72/te_72
dtenorm_low_adj72 = dte_low_adj72/te_72

dtenorm_up_adj96 = dte_up_adj96/te_96
dtenorm_low_adj96 = dte_low_adj96/te_96

dtenorm_up_wave48 = dte_up_wave48/te_48
dtenorm_low_wave48 = dte_low_wave48/te_48

dtenorm_up_wave72 = dte_up_wave72/te_72
dtenorm_low_wave72 = dte_low_wave72/te_72

dtenorm_up_wave96 = dte_up_wave96/te_96
dtenorm_low_wave96 = dte_low_wave96/te_96

dtenorm_up_adj48_10 = dte_up_adj48_10/te_48
dtenorm_low_adj48_10 = dte_low_adj48_10/te_48

dtenorm_up_adj72_10 = dte_up_adj72_10/te_72
dtenorm_low_adj72_10 = dte_low_adj72_10/te_72

dtenorm_up_adj96_10 = dte_up_adj96_10/te_96
dtenorm_low_adj96_10 = dte_low_adj96_10/te_96

dtenorm_up_wave48_10 = dte_up_wave48_10/te_48
dtenorm_low_wave48_10 = dte_low_wave48_10/te_48

dtenorm_up_wave72_10 = dte_up_wave72_10/te_72
dtenorm_low_wave72_10 = dte_low_wave72_10/te_72

dtenorm_up_wave96_10 = dte_up_wave96_10/te_96
dtenorm_low_wave96_10 = dte_low_wave96_10/te_96

dtenorm_up_adj48_100 = dte_up_adj48_100/te_48
dtenorm_low_adj48_100 = dte_low_adj48_100/te_48

dtenorm_up_adj72_100 = dte_up_adj72_100/te_72
dtenorm_low_adj72_100 = dte_low_adj72_100/te_72

dtenorm_up_adj96_100 = dte_up_adj96_100/te_96
dtenorm_low_adj96_100 = dte_low_adj96_100/te_96

dtenorm_up_wave48_100 = dte_up_wave48_100/te_48
dtenorm_low_wave48_100 = dte_low_wave48_100/te_48

dtenorm_up_wave72_100 = dte_up_wave72_100/te_72
dtenorm_low_wave72_100 = dte_low_wave72_100/te_72

dtenorm_up_wave96_100 = dte_up_wave96_100/te_96
dtenorm_low_wave96_100 = dte_low_wave96_100/te_96

# %%
fig,axd = plt.subplot_mosaic([['left','right']],figsize=(7.0,4.0),dpi=200,constrained_layout=True)

trans1 = mtransforms.ScaledTranslation(1/12, 1/5, fig.dpi_scale_trans)
trans2 = mtransforms.ScaledTranslation(1/12, 1/5, fig.dpi_scale_trans)

axd['left'].plot(dtenorm_low_adj48[:80],zp[:80]/1000.,color='blue',label='48 h')
axd['left'].plot(dtenorm_up_adj48[:80],zp[:80]/1000.,color='blue',linestyle='dashed')
axd['left'].plot(dtenorm_low_adj72[:80],zp[:80]/1000.,color='orange',label='72 h')
axd['left'].plot(dtenorm_up_adj72[:80],zp[:80]/1000.,color='orange',linestyle='dashed')
axd['left'].plot(dtenorm_low_adj96[:80],zp[:80]/1000.,color='green',label='96 h')
axd['left'].plot(dtenorm_up_adj96[:80],zp[:80]/1000.,color='green',linestyle='dashed')
axd['left'].set_xlabel('DTE')
axd['left'].set_ylabel('Height (km)')
axd['left'].legend()
axd['left'].set_yticks(np.linspace(0,16,9))
axd['left'].grid()
#axd['left'].set_xlim(-0.5e-5,5.5e-5)
axd['left'].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
axd['left'].text(0.0, 1.0, '(a) Adjoint',transform=axd['left'].transAxes + trans1,
            fontsize=12, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['right'].plot(dtenorm_low_wave48[:80],zp[:80]/1000.,color='blue',label='48 h')
axd['right'].plot(dtenorm_up_wave48[:80],zp[:80]/1000.,color='blue',linestyle='dashed')
axd['right'].plot(dtenorm_low_wave72[:80],zp[:80]/1000.,color='orange',label='72 h')
axd['right'].plot(dtenorm_up_wave72[:80],zp[:80]/1000.,color='orange',linestyle='dashed')
axd['right'].plot(dtenorm_low_wave96[:80],zp[:80]/1000.,color='green',label='96 h')
axd['right'].plot(dtenorm_up_wave96[:80],zp[:80]/1000.,color='green',linestyle='dashed')
axd['right'].set_xlabel('DTE')
#axd['right'].set_xlim(-0.5e-5,5.5e-5)
axd['right'].set_yticks(np.linspace(0,16,9))
axd['right'].set_yticklabels(['','','','','','','','',''])
axd['right'].grid()
axd['right'].ticklabel_format(axis="x", style="sci", scilimits=(0,0))
axd['right'].text(0.0, 1.0, '(b) Wave',transform=axd['right'].transAxes + trans2,
            fontsize=12, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))
