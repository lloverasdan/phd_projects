# %%
# %pylab inline
import matplotlib
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import numpy as np
from matplotlib.cm import get_cmap
from matplotlib.ticker import MultipleLocator
import warnings
warnings.filterwarnings('ignore')
import matplotlib.transforms as mtransforms

sat_short_adj = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_adj_48h.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_adj = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_adj_48h.npy')

sat_long_adj = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_adj_48h.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_adj = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_adj_48h.npy')

sat_short_wave = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_wave_48h.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_wave = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_wave_48h.npy')

sat_long_wave = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_wave_48h.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_wave = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_wave_48h.npy')

sat_short_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_adj_48h_10.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_adj_48h_10.npy')

sat_long_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_adj_48h_10.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_adj_48h_10.npy')

sat_short_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_wave_48h_10.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_wave_48h_10.npy')

sat_long_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_wave_48h_10.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_wave_48h_10.npy')

sat_short_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_adj_48h_100.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_adj_48h_100.npy')

sat_long_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_adj_48h_100.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_adj_48h_100.npy')

sat_short_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_wave_48h_100.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/spec_ctl_48h.npy')
pert_short_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/short_runs/dtespec_wave_48h_100.npy')

sat_long_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_wave_48h_100.npy') +\
            np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/spec_ctl_48h.npy')
pert_long_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/spectra/long_runs/dtespec_wave_48h_100.npy')

n = 500
wavenumber=np.arange(0,n)
zmin1 = 0
zmax1 = 100
k3_ind = np.arange(5,15,1)
k3_val = k3_ind**(-3.0)*5.75e7
k2_ind = np.arange(40,190,1)
k2_val = k2_ind**(-2.)*1.0e6
pert_short_adj[0,:,120:] = np.zeros((90,2426))

# %%
fig, axd = plt.subplot_mosaic([['left','right']],
                              constrained_layout=True, figsize=(12.0,7.5))

trans = mtransforms.ScaledTranslation(1/25, -1/25, fig.dpi_scale_trans)

axd_left = axd['left'].twiny()
axd['left'].plot(wavenumber,np.mean(sat_long_adj_100[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['left'].plot(wavenumber,np.mean(pert_short_adj_100[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
# axd['left'].plot(wavenumber,np.mean(pert_short_adj_100[6,zmin1:zmax1,:n],axis=0),
#          label='3 h',color='green',linewidth=3.1,linestyle='dashed')
# axd['left'].plot(wavenumber,np.mean(pert_long_adj_100[1,zmin1:zmax1,:n],axis=0),
#          label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['left'].plot(wavenumber,np.mean(pert_long_adj_100[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['left'].plot(wavenumber,np.mean(pert_long_adj_100[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='darkorange',linewidth=3.1,linestyle='dashed')
axd['left'].plot(wavenumber,np.mean(pert_long_adj_100[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['left'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['left'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['left'].set_xscale('log') 
axd['left'].set_yscale('log')
axd['left'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['left'].set_ylabel("DTE (m$^3$ s$^{-2}$)",fontsize=20,labelpad=6) 
axd['left'].tick_params(axis='both',labelsize=20,pad=6)
axd['left'].tick_params(which='major',direction='in',length=8)
axd['left'].tick_params(which='minor',direction='in',length=4)
axd['left'].set_xlim([1,n])
axd['left'].set_ylim([1e-4,1e6])
axd['left'].grid(which='major',linewidth=1.5)
axd['left'].legend(fontsize=16,loc=1)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['left'].yaxis.set_major_locator(locmaj)
axd['left'].set_yticklabels(['','$10^{-4}$','','$10^{-2}$','','$10^{0}$','','$10^2$','','$10^4$','','$10^6$',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['left'].yaxis.set_minor_locator(locmin)
axd['left'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd_left.set_xlim([16,8000])
axd_left.set_xscale('log')
axd_left.invert_xaxis()
axd_left.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_left.tick_params(axis='both',labelsize=20,pad=6)
axd_left.tick_params(which='major',direction='in',length=8)
axd_left.tick_params(which='minor',direction='in',length=4)
axd['left'].text(0.015, 0.775, '(a) Adjoint/100',transform=axd['left'].transAxes + trans,
            fontsize=17, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_right = axd['right'].twiny()
axd['right'].plot(wavenumber,np.mean(sat_long_wave_100[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['right'].plot(wavenumber,np.mean(pert_short_wave_100[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
# axd['right'].plot(wavenumber,np.mean(pert_short_wave_100[6,zmin1:zmax1,:n],axis=0),
#          label='3 h',color='green',linewidth=3.1,linestyle='dashed')
# axd['right'].plot(wavenumber,np.mean(pert_long_wave_100[1,zmin1:zmax1,:n],axis=0),
#          label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['right'].plot(wavenumber,np.mean(pert_long_wave_100[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['right'].plot(wavenumber,np.mean(pert_long_wave_100[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='darkorange',linewidth=3.1,linestyle='dashed')
axd['right'].plot(wavenumber,np.mean(pert_long_wave_100[8,zmin1:zmax1,:n]*1.2,axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['right'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['right'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['right'].set_xscale('log') 
axd['right'].set_yscale('log')
axd['right'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['right'].tick_params(axis='both',labelsize=20,pad=6,labelleft=False)
axd['right'].tick_params(which='major',direction='in',length=8)
axd['right'].tick_params(which='minor',direction='in',length=4)
axd['right'].set_xlim([1,n])
axd['right'].set_ylim([1e-4,1e6])
axd['right'].grid(which='major',linewidth=1.5)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['right'].yaxis.set_major_locator(locmaj)
axd['right'].set_yticklabels(['','','','','','','','','','','','',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['right'].yaxis.set_minor_locator(locmin)
axd['right'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
# xfill=wavenumber[40:100]
# yfill1=np.mean(pert_short_wave_100[6,zmin1:zmax1,40:100],axis=0)
# yfill2=np.mean(pert_long_wave_100[8,zmin1:zmax1,40:100],axis=0)
# axd['right'].fill_between(xfill,yfill1,yfill2,alpha=0.3,facecolor='grey')
axd_right.set_xlim([16,8000])
axd_right.set_xscale('log')
axd_right.invert_xaxis()
axd_right.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_right.tick_params(axis='both',labelsize=20,pad=6)
axd_right.tick_params(which='major',direction='in',length=8)
axd_right.tick_params(which='minor',direction='in',length=4)
axd['right'].text(0.015, 0.775, '(b) Wave/100',transform=axd['right'].transAxes + trans,
            fontsize=17, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

plt.savefig('/p/work1/lloveras/adj_4km/figs_june/spectra_100.pdf',bbox_inches='tight')

# %%
fig, axd = plt.subplot_mosaic([['top left','top center','top right'],
                              ['bottom left','bottom center','bottom right']],
                              constrained_layout=True, figsize=(15.5,13.0))

trans = mtransforms.ScaledTranslation(1/25, -1/25, fig.dpi_scale_trans)

axd_lefttop = axd['top left'].twiny()
axd['top left'].plot(wavenumber,np.mean(sat_long_adj[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['top left'].plot(wavenumber,np.mean(pert_short_adj[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(wavenumber,np.mean(pert_short_adj[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(wavenumber,np.mean(pert_long_adj[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(wavenumber,np.mean(pert_long_adj[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(wavenumber,np.mean(pert_long_adj[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(wavenumber,np.mean(pert_long_adj[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['top left'].plot(k3_ind,k3_val*1.75,color='grey',linewidth=3.5)
axd['top left'].plot(k2_ind,k2_val*1.75,color='grey',linewidth=4.0,linestyle='dotted')
axd['top left'].set_xscale('log') 
axd['top left'].set_yscale('log')
axd['top left'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['top left'].set_ylabel("DTE (m$^3$ s$^{-2}$)",fontsize=20,labelpad=6) 
axd['top left'].tick_params(axis='both',labelsize=20,pad=6)
axd['top left'].tick_params(which='major',direction='in',length=8)
axd['top left'].tick_params(which='minor',direction='in',length=4)
axd['top left'].set_xlim([1,n])
axd['top left'].set_ylim([1e-4,1e6])
axd['top left'].grid(which='major',linewidth=1.5)
axd['top left'].legend(fontsize=16,loc=0)
axd['top left'].set_title('Full',pad=12,fontsize=24)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['top left'].yaxis.set_major_locator(locmaj)
axd['top left'].set_yticklabels(['','$10^{-4}$','','$10^{-2}$','','$10^{0}$','','$10^2$','','$10^4$','','$10^6$',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['top left'].yaxis.set_minor_locator(locmin)
axd['top left'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd['top left'].text(-0.65, 0.5, 'Adjoint',transform=axd['top left'].transAxes + trans,
            fontsize=24, verticalalignment='top')
axd_lefttop.set_xlim([16,8000])
axd_lefttop.set_xscale('log')
axd_lefttop.invert_xaxis()
axd_lefttop.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_lefttop.tick_params(axis='both',labelsize=20,pad=6)
axd_lefttop.tick_params(which='major',direction='in',length=8)
axd_lefttop.tick_params(which='minor',direction='in',length=4)
axd['top left'].text(0.005, 0.985, '(a)',transform=axd['top left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_leftbot = axd['bottom left'].twiny()
axd['bottom left'].plot(wavenumber,np.mean(sat_long_wave[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['bottom left'].plot(wavenumber,np.mean(pert_short_wave[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(wavenumber,np.mean(pert_short_wave[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(wavenumber,np.mean(pert_long_wave[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(wavenumber,np.mean(pert_long_wave[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(wavenumber,np.mean(pert_long_wave[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(wavenumber,np.mean(pert_long_wave[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['bottom left'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['bottom left'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['bottom left'].set_xscale('log') 
axd['bottom left'].set_yscale('log')
axd['bottom left'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['bottom left'].tick_params(axis='both',labelsize=20,pad=6)
axd['bottom left'].tick_params(which='major',direction='in',length=8)
axd['bottom left'].tick_params(which='minor',direction='in',length=4)
axd['bottom left'].set_xlim([1,n])
axd['bottom left'].set_ylim([1e-4,1e6])
axd['bottom left'].grid(which='major',linewidth=1.5)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['bottom left'].yaxis.set_major_locator(locmaj)
axd['bottom left'].set_yticklabels(['','$10^{-4}$','','$10^{-2}$','','$10^{0}$','','$10^2$','','$10^4$','','$10^6$',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['bottom left'].yaxis.set_minor_locator(locmin)
axd['bottom left'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd['bottom left'].set_ylabel("DTE (m$^3$ s$^{-2}$)",fontsize=20,labelpad=6)
axd['bottom left'].text(-0.6, 0.5, 'Wave',transform=axd['bottom left'].transAxes + trans,
            fontsize=24, verticalalignment='top')
axd_leftbot.set_xlim([16,8000])
axd_leftbot.set_xscale('log')
axd_leftbot.invert_xaxis()
axd_leftbot.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_leftbot.tick_params(axis='both',labelsize=20,pad=6)
axd_leftbot.tick_params(which='major',direction='in',length=8)
axd_leftbot.tick_params(which='minor',direction='in',length=4)
axd['bottom left'].text(0.005, 0.985, '(d)',transform=axd['bottom left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_centertop = axd['top center'].twiny()
axd['top center'].plot(wavenumber,np.mean(sat_long_adj_10[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['top center'].plot(wavenumber,np.mean(pert_short_adj_10[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(wavenumber,np.mean(pert_short_adj_10[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(wavenumber,np.mean(pert_long_adj_10[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(wavenumber,np.mean(pert_long_adj_10[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(wavenumber,np.mean(pert_long_adj_10[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(wavenumber,np.mean(pert_long_adj_10[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['top center'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['top center'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['top center'].set_xscale('log') 
axd['top center'].set_yscale('log')
axd['top center'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['top center'].tick_params(axis='both',labelsize=20,pad=6,labelleft=False)
axd['top center'].tick_params(which='major',direction='in',length=8)
axd['top center'].tick_params(which='minor',direction='in',length=4)
axd['top center'].set_xlim([1,n])
axd['top center'].set_ylim([1e-4,1e6])
axd['top center'].grid(which='major',linewidth=1.5)
axd['top center'].set_title('1/10',pad=12,fontsize=24)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['top center'].yaxis.set_major_locator(locmaj)
axd['top center'].set_yticklabels(['','','','','','','','','','','','',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['top center'].yaxis.set_minor_locator(locmin)
axd['top center'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd_centertop.set_xlim([16,8000])
axd_centertop.set_xscale('log')
axd_centertop.invert_xaxis()
axd_centertop.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_centertop.tick_params(axis='both',labelsize=20,pad=6)
axd_centertop.tick_params(which='major',direction='in',length=8)
axd_centertop.tick_params(which='minor',direction='in',length=4)
axd['top center'].text(0.005, 0.985, '(b)',transform=axd['top center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_centerbot = axd['bottom center'].twiny()
axd['bottom center'].plot(wavenumber,np.mean(sat_long_wave_10[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['bottom center'].plot(wavenumber,np.mean(pert_short_wave_10[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(wavenumber,np.mean(pert_short_wave_10[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(wavenumber,np.mean(pert_long_wave_10[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(wavenumber,np.mean(pert_long_wave_10[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(wavenumber,np.mean(pert_long_wave_10[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(wavenumber,np.mean(pert_long_wave_10[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['bottom center'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['bottom center'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['bottom center'].set_xscale('log') 
axd['bottom center'].set_yscale('log')
axd['bottom center'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['bottom center'].tick_params(axis='both',labelsize=20,pad=6,labelleft=False)
axd['bottom center'].tick_params(which='major',direction='in',length=8)
axd['bottom center'].tick_params(which='minor',direction='in',length=4)
axd['bottom center'].set_xlim([1,n])
axd['bottom center'].set_ylim([1e-4,1e6])
axd['bottom center'].grid(which='major',linewidth=1.5)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['bottom center'].yaxis.set_major_locator(locmaj)
axd['bottom center'].set_yticklabels(['','','','','','','','','','','','',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['bottom center'].yaxis.set_minor_locator(locmin)
axd['bottom center'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd_centerbot.set_xlim([16,8000])
axd_centerbot.set_xscale('log')
axd_centerbot.invert_xaxis()
axd_centerbot.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_centerbot.tick_params(axis='both',labelsize=20,pad=6)
axd_centerbot.tick_params(which='major',direction='in',length=8)
axd_centerbot.tick_params(which='minor',direction='in',length=4)
axd['bottom center'].text(0.005, 0.985, '(e)',transform=axd['bottom center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_righttop = axd['top right'].twiny()
axd['top right'].plot(wavenumber,np.mean(sat_long_adj_100[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['top right'].plot(wavenumber,np.mean(pert_short_adj_100[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(wavenumber,np.mean(pert_short_adj_100[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(wavenumber,np.mean(pert_long_adj_100[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(wavenumber,np.mean(pert_long_adj_100[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(wavenumber,np.mean(pert_long_adj_100[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(wavenumber,np.mean(pert_long_adj_100[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['top right'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['top right'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['top right'].set_xscale('log') 
axd['top right'].set_yscale('log')
axd['top right'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['top right'].tick_params(axis='both',labelsize=20,pad=6,labelleft=False)
axd['top right'].tick_params(which='major',direction='in',length=8)
axd['top right'].tick_params(which='minor',direction='in',length=4)
axd['top right'].set_xlim([1,n])
axd['top right'].set_ylim([1e-4,1e6])
axd['top right'].grid(which='major',linewidth=1.5)
axd['top right'].set_title('1/100',pad=12,fontsize=24)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['top right'].yaxis.set_major_locator(locmaj)
axd['top right'].set_yticklabels(['','','','','','','','','','','','',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['top right'].yaxis.set_minor_locator(locmin)
axd['top right'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd_righttop.set_xlim([16,8000])
axd_righttop.set_xscale('log')
axd_righttop.invert_xaxis()
axd_righttop.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_righttop.tick_params(axis='both',labelsize=20,pad=6)
axd_righttop.tick_params(which='major',direction='in',length=8)
axd_righttop.tick_params(which='minor',direction='in',length=4)
axd['top right'].text(0.005, 0.985, '(c)',transform=axd['top right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

axd_rightbot = axd['bottom right'].twiny()
axd['bottom right'].plot(wavenumber,np.mean(sat_long_wave_100[8,zmin1:zmax1,:n],axis=0),
         color='black',linewidth=3.5)
axd['bottom right'].plot(wavenumber,np.mean(pert_short_wave_100[0,zmin1:zmax1,:n],axis=0),
         label='0 h',color='blue',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(wavenumber,np.mean(pert_short_wave_100[6,zmin1:zmax1,:n],axis=0),
         label='3 h',color='green',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(wavenumber,np.mean(pert_long_wave_100[1,zmin1:zmax1,:n],axis=0),
         label='6 h',color='c',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(wavenumber,np.mean(pert_long_wave_100[2,zmin1:zmax1,:n],axis=0),
         label='12 h',color='purple',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(wavenumber,np.mean(pert_long_wave_100[5,zmin1:zmax1,:n],axis=0),
         label='30 h',color='orange',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(wavenumber,np.mean(pert_long_wave_100[8,zmin1:zmax1,:n],axis=0),
         label='48 h',color='red',linewidth=3.1,linestyle='dashed')
axd['bottom right'].plot(k3_ind,k3_val,color='grey',linewidth=3.5)
axd['bottom right'].plot(k2_ind,k2_val,color='grey',linewidth=4.0,linestyle='dotted')
axd['bottom right'].set_xscale('log') 
axd['bottom right'].set_yscale('log')
axd['bottom right'].set_xlabel("Wavenumber ($k_{p}/\Delta k_{h}$)",fontsize=20) 
axd['bottom right'].tick_params(axis='both',labelsize=20,pad=6,labelright=False)
axd['bottom right'].tick_params(which='major',direction='in',length=8)
axd['bottom right'].tick_params(which='minor',direction='in',length=4)
axd['bottom right'].set_xlim([1,n])
axd['bottom right'].set_ylim([1e-4,1e6])
axd['bottom right'].grid(which='major',linewidth=1.5)
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=12) 
axd['bottom right'].yaxis.set_major_locator(locmaj)
axd['bottom right'].set_yticklabels(['','','','','','','','','','','','',''])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=12)
axd['bottom right'].yaxis.set_minor_locator(locmin)
axd['bottom right'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd_rightbot.set_xlim([16,8000])
axd_rightbot.set_xscale('log')
axd_rightbot.invert_xaxis()
axd_rightbot.set_xlabel("Wavelength (km)",fontsize=20,labelpad=10)
axd_rightbot.tick_params(axis='both',labelsize=20,pad=6)
axd_rightbot.tick_params(which='major',direction='in',length=8)
axd_rightbot.tick_params(which='minor',direction='in',length=4)
axd['bottom right'].text(0.005, 0.985, '(f)',transform=axd['bottom right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

plt.savefig('/p/work1/lloveras/adj_4km/spectra_all.pdf',bbox_inches='tight')
