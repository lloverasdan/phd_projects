# %%
# %pylab inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator
import warnings
warnings.filterwarnings('ignore')
import matplotlib.transforms as mtransforms

nt = 17
nt_short = 13
time = np.arange(nt)*3

time_short = [x for x in list(range(int((nt_short - 1)/2)+1))]
time_long = [x*3 + 6 for x in list(range(nt - 2))]

dte_adj = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_48h.npy')
dte_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_48h_10.npy')
dte_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_48h_100.npy')
dte_wave = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_48h.npy')
dte_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_48h_10.npy')
dte_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_48h_100.npy')

dte_adj_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_48h.npy')
dte_wave_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_48h.npy')
dte_adj_short_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_48h_10.npy')
dte_wave_short_10 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_48h_10.npy')
dte_adj_short_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_48h_100.npy')
dte_wave_short_100 = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_48h_100.npy')

mag_adj = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_48h.npy')
mag_adj_10 = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_48h_10.npy')
mag_adj_100 = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_48h_100.npy')
mag_wave = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_48h.npy')
mag_wave_10 = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_48h_10.npy')
mag_wave_100 = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_48h_100.npy')

fss_adj = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_48h.npy'))
fss_adj_10 = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_48h_10.npy'))
fss_adj_100 = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_48h_100.npy'))
fss_wave = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_48h.npy'))
fss_wave_10 = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_48h_10.npy'))
fss_wave_100 = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_48h_100.npy'))


mag_adj[0] = 0.
mag_adj_10[0] = 0.
mag_adj_100[0] = 0.
mag_wave[0] = 0.
mag_wave_10[0] = 0.
mag_wave_100[0] = 0.

# %%
fig, axd = plt.subplot_mosaic([['top left', 'top right'],
                                ['bottom left', 'bottom right']],
                              constrained_layout=True, figsize=(14.0,9.5),dpi=300,
                              gridspec_kw={'width_ratios':[1,1],'height_ratios':[1,1]})

trans = mtransforms.ScaledTranslation(1/10, -1/10, fig.dpi_scale_trans)

axd['top left'].plot(time_short,dte_adj_short[::2],color='r',linewidth=3.0,label='Adjoint')
axd['top left'].plot(time_long,dte_adj[2:],color='r',linewidth=3.0)
axd['top left'].plot(time_short,dte_wave_short[::2],color='b',linewidth=3.0,label='Wave')
axd['top left'].plot(time_long,dte_wave[2:],color='b',linewidth=3.0)
axd['top left'].plot(time_short,dte_adj_short_10[::2],color='r',linewidth=3.0,linestyle='dashed')
axd['top left'].plot(time_long,dte_adj_10[2:],color='r',linewidth=3.0,linestyle='dashed')
axd['top left'].plot(time_short,dte_wave_short_10[::2],color='b',linewidth=3.0,linestyle='dashed')
axd['top left'].plot(time_long,dte_wave_10[2:],color='b',linewidth=3.0,linestyle='dashed')
axd['top left'].plot(time_short,dte_adj_short_100[::2],color='r',linewidth=3.0,linestyle='dotted')
axd['top left'].plot(time_long,dte_adj_100[2:],color='r',linewidth=3.0,linestyle='dotted')
axd['top left'].plot(time_short,dte_wave_short_100[::2],color='b',linewidth=3.0,linestyle='dotted')
axd['top left'].plot(time_long,dte_wave_100[2:],color='b',linewidth=3.0,linestyle='dotted')
axd['top left'].legend(prop={"size":18})
axd['top left'].set_ylabel('DTE (m$^2$ s$^{-2}$)',labelpad=6,fontsize=20)
axd['top left'].xaxis.set_major_locator(MultipleLocator(6))
axd['top left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['top left'].set_xticklabels(['','','','','','','','','',''])
axd['top left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['top left'].legend(loc=4,prop={"size":18})
axd['top left'].set_yscale('log')
axd['top left'].set_ylim([1e0,1e9])
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=10) 
axd['top left'].yaxis.set_major_locator(locmaj)
axd['top left'].set_yticklabels(['','','$10^{1}$','','$10^{3}$','','$10^{5}$','','$10^{7}$','','$10^{9}$'])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=10)
axd['top left'].yaxis.set_minor_locator(locmin)
axd['top left'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd['top left'].grid(linewidth=1.5)
axd['top left'].text(0.0, 1.0, '(a)',transform=axd['top left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['top right'].plot(time_short,dte_adj_short[::2]/1e6,color='r',linewidth=3.0,label='Adjoint')
axd['top right'].plot(time_long,dte_adj[2:]/1e6,color='r',linewidth=3.0)
axd['top right'].plot(time_short,dte_wave_short[::2]/1e6,color='b',linewidth=3.0,label='Wave')
axd['top right'].plot(time_long,dte_wave[2:]/1e6,color='b',linewidth=3.0)
axd['top right'].plot(time_short,dte_adj_short_10[::2]/1e6,color='r',linewidth=3.0,linestyle='dashed')
axd['top right'].plot(time_long,dte_adj_10[2:]/1e6,color='r',linewidth=3.0,linestyle='dashed')
axd['top right'].plot(time_short,dte_wave_short_10[::2]/1e6,color='b',linewidth=3.0,linestyle='dashed')
axd['top right'].plot(time_long,dte_wave_10[2:]/1e6,color='b',linewidth=3.0,linestyle='dashed')
axd['top right'].plot(time_short,dte_adj_short_100[::2]/1e6,color='r',linewidth=3.0,linestyle='dotted')
axd['top right'].plot(time_long,dte_adj_100[2:]/1e6,color='r',linewidth=3.0,linestyle='dotted')
axd['top right'].plot(time_short,dte_wave_short_100[::2]/1e6,color='b',linewidth=3.0,linestyle='dotted')
axd['top right'].plot(time_long,dte_wave_100[2:]/1e6,color='b',linewidth=3.0,linestyle='dotted')
axd['top right'].set_xticklabels(['','','','','','','','','',''])
axd['top right'].set_ylabel('DTE (10$^6$ m$^2$ s$^{-2}$)',labelpad=6,fontsize=20)
axd['top right'].set_ylim([-1,9])
axd['top right'].xaxis.set_major_locator(MultipleLocator(6))
axd['top right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['top right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['top right'].grid(linewidth=1.5)
axd['top right'].text(0.0, 1.0, '(b)',transform=axd['top right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['bottom left'].plot(time,mag_adj,color='r',label='Adjoint',linewidth=3.0)
axd['bottom left'].plot(time,mag_adj_10,color='r',linestyle='dashed',linewidth=3.0)
axd['bottom left'].plot(time,mag_adj_100,color='r',linestyle='dotted',linewidth=3.0)
axd['bottom left'].plot(time,mag_wave,color='b',label='Wave',linewidth=3.0)
axd['bottom left'].plot(time,mag_wave_10,color='b',linestyle='dashed',linewidth=3.0)
axd['bottom left'].plot(time,mag_wave_100,color='b',linestyle='dotted',linewidth=3.0)
axd['bottom left'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['bottom left'].set_ylabel('Pressure Difference (hPa)',labelpad=6,fontsize=20)
axd['bottom left'].xaxis.set_major_locator(MultipleLocator(6))
axd['bottom left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['bottom left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['bottom left'].grid(linewidth=1.5)
axd['bottom left'].set_ylim([-9,1.5])
axd['bottom left'].text(0.0, 1.0, '(c)',transform=axd['bottom left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['bottom right'].plot(time,fss_adj,color='r',label='Adjoint',linewidth=3.0)
axd['bottom right'].plot(time,fss_adj_10,color='r',linestyle='dashed',linewidth=3.0)
axd['bottom right'].plot(time,fss_adj_100,color='r',linestyle='dotted',linewidth=3.0)
axd['bottom right'].plot(time,fss_wave,color='b',label='Wave',linewidth=3.0)
axd['bottom right'].plot(time,fss_wave_10,color='b',linestyle='dashed',linewidth=3.0)
axd['bottom right'].plot(time,fss_wave_100,color='b',linestyle='dotted',linewidth=3.0)
axd['bottom right'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['bottom right'].set_ylabel('FSS',labelpad=6,fontsize=20)
axd['bottom right'].xaxis.set_major_locator(MultipleLocator(6))
axd['bottom right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['bottom right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['bottom right'].grid(linewidth=1.5)
axd['bottom right'].set_ylim([0.12,1.12])
axd['bottom right'].text(0.0, 1.0, '(d)',transform=axd['bottom right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

#plt.savefig('/p/work1/lloveras/adj_4km/figs/new_figs/norms.pdf',bbox_inches='tight')

# %%
fig, axd = plt.subplot_mosaic([['left', 'right']],
                              constrained_layout=True, figsize=(14.0,5.5),dpi=300)

trans = mtransforms.ScaledTranslation(1/10, -1/10, fig.dpi_scale_trans)

axd['left'].plot(time,mag_adj,color='r',label='Adjoint',linewidth=3.0)
# axd['left'].plot(time,mag_adj_10,color='r',linestyle='dashed',linewidth=3.0)
# axd['left'].plot(time,mag_adj_100,color='r',linestyle='dotted',linewidth=3.0)
axd['left'].plot(time,mag_wave,color='b',label='Wave',linewidth=3.0)
# axd['left'].plot(time,mag_wave_10,color='b',linestyle='dashed',linewidth=3.0)
# axd['left'].plot(time,mag_wave_100,color='b',linestyle='dotted',linewidth=3.0)
axd['left'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['left'].set_ylabel('Pressure Difference (hPa)',labelpad=6,fontsize=20)
axd['left'].xaxis.set_major_locator(MultipleLocator(6))
axd['left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['left'].grid(linewidth=1.5)
axd['left'].set_ylim([-9,1.5])
axd['left'].legend(loc=0,prop={"size":18})
axd['left'].text(0.0, 1.0, '(a)',transform=axd['left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['right'].plot(time,fss_adj,color='r',label='Adjoint',linewidth=3.0)
# axd['right'].plot(time,fss_adj_10,color='r',linestyle='dashed',linewidth=3.0)
# axd['right'].plot(time,fss_adj_100,color='r',linestyle='dotted',linewidth=3.0)
axd['right'].plot(time,fss_wave,color='b',label='Wave',linewidth=3.0)
# axd['right'].plot(time,fss_wave_10,color='b',linestyle='dashed',linewidth=3.0)
# axd['right'].plot(time,fss_wave_100,color='b',linestyle='dotted',linewidth=3.0)
axd['right'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['right'].set_ylabel('FSS',labelpad=6,fontsize=20)
axd['right'].xaxis.set_major_locator(MultipleLocator(6))
axd['right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['right'].grid(linewidth=1.5)
axd['right'].set_ylim([0.12,1.12])
axd['right'].text(0.0, 1.0, '(b)',transform=axd['right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

plt.savefig('/p/work1/lloveras/adj_4km/meso_figs/slp_fss_full.pdf',bbox_inches='tight')

# %%
fig, axd = plt.subplot_mosaic([['left', 'right']],
                              constrained_layout=True, figsize=(14.0,5.5),dpi=300)

trans = mtransforms.ScaledTranslation(1/10, -1/10, fig.dpi_scale_trans)

axd['left'].plot(time_short,dte_adj_short[::2],color='r',linewidth=3.0,label='Adjoint')
axd['left'].plot(time_long,dte_adj[2:],color='r',linewidth=3.0)
axd['left'].plot(time_short,dte_wave_short[::2],color='b',linewidth=3.0,label='Wave')
axd['left'].plot(time_long,dte_wave[2:],color='b',linewidth=3.0)
axd['left'].plot(time_short,dte_adj_short_10[::2],color='r',linewidth=3.0,linestyle='dashed')
axd['left'].plot(time_long,dte_adj_10[2:],color='r',linewidth=3.0,linestyle='dashed')
axd['left'].plot(time_short,dte_wave_short_10[::2],color='b',linewidth=3.0,linestyle='dashed')
axd['left'].plot(time_long,dte_wave_10[2:],color='b',linewidth=3.0,linestyle='dashed')
axd['left'].plot(time_short,dte_adj_short_100[::2],color='r',linewidth=3.0,linestyle='dotted')
axd['left'].plot(time_long,dte_adj_100[2:],color='r',linewidth=3.0,linestyle='dotted')
axd['left'].plot(time_short,dte_wave_short_100[::2],color='b',linewidth=3.0,linestyle='dotted')
axd['left'].plot(time_long,dte_wave_100[2:],color='b',linewidth=3.0,linestyle='dotted')
axd['left'].legend(prop={"size":18})
axd['left'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['left'].set_ylabel('DTE (m$^2$ s$^{-2}$)',labelpad=6,fontsize=20)
axd['left'].xaxis.set_major_locator(MultipleLocator(6))
axd['left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['left'].legend(loc=4,prop={"size":18})
axd['left'].set_yscale('log')
axd['left'].set_ylim([1e0,1e9])
locmaj = matplotlib.ticker.LogLocator(base=10,numticks=10) 
axd['left'].yaxis.set_major_locator(locmaj)
axd['left'].set_yticklabels(['','','$10^{1}$','','$10^{3}$','','$10^{5}$','','$10^{7}$','','$10^{9}$'])
locmin = matplotlib.ticker.LogLocator(base=10.0,subs=(0.2,0.4,0.6,0.8),numticks=10)
axd['left'].yaxis.set_minor_locator(locmin)
axd['left'].yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())
axd['left'].grid(linewidth=1.5)
axd['left'].text(0.0, 1.0, '(a)',transform=axd['left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['right'].plot(time_short,dte_adj_short[::2]/1e6,color='r',linewidth=3.0,label='Adjoint')
axd['right'].plot(time_long,dte_adj[2:]/1e6,color='r',linewidth=3.0)
axd['right'].plot(time_short,dte_wave_short[::2]/1e6,color='b',linewidth=3.0,label='Wave')
axd['right'].plot(time_long,dte_wave[2:]/1e6,color='b',linewidth=3.0)
axd['right'].plot(time_short,dte_adj_short_10[::2]/1e6,color='r',linewidth=3.0,linestyle='dashed')
axd['right'].plot(time_long,dte_adj_10[2:]/1e6,color='r',linewidth=3.0,linestyle='dashed')
axd['right'].plot(time_short,dte_wave_short_10[::2]/1e6,color='b',linewidth=3.0,linestyle='dashed')
axd['right'].plot(time_long,dte_wave_10[2:]/1e6,color='b',linewidth=3.0,linestyle='dashed')
axd['right'].plot(time_short,dte_adj_short_100[::2]/1e6,color='r',linewidth=3.0,linestyle='dotted')
axd['right'].plot(time_long,dte_adj_100[2:]/1e6,color='r',linewidth=3.0,linestyle='dotted')
axd['right'].plot(time_short,dte_wave_short_100[::2]/1e6,color='b',linewidth=3.0,linestyle='dotted')
axd['right'].plot(time_long,dte_wave_100[2:]/1e6,color='b',linewidth=3.0,linestyle='dotted')
axd['right'].set_ylabel('DTE (10$^6$ m$^2$ s$^{-2}$)',labelpad=6,fontsize=20)
axd['right'].set_ylim([-1,9])
axd['right'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['right'].xaxis.set_major_locator(MultipleLocator(6))
axd['right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['right'].grid(linewidth=1.5)
axd['right'].text(0.0, 1.0, '(b)',transform=axd['right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

plt.savefig('/p/work1/lloveras/adj_4km/figs/new_figs/dte_time.pdf',bbox_inches='tight')

# %%
dte_adj48h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_48h.npy')
dte_adj72h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_72h.npy')
dte_adj96h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_adj_96h.npy')
dte_wave48h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_48h.npy')
dte_wave72h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_72h.npy')
dte_wave96h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/long_runs/dte_wave_96h.npy')

dte_adj48h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_48h.npy')
dte_wave48h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_48h.npy')
dte_adj72h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_72h.npy')
dte_wave72h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_72h.npy')
dte_adj96h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_adj_96h.npy')
dte_wave96h_short = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/short_runs/dte_wave_96h.npy')

tot_48h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/tot_48h.npy')
tot_72h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/tot_72h.npy')
tot_96h = np.load('/p/work1/lloveras/adj_4km/processed/dte/domain_integrated/tot_96h.npy')

mag_adj48h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_48h.npy')
mag_adj72h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_72h.npy')
mag_adj96h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_96h.npy')
mag_wave48h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_48h.npy')
mag_wave72h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_72h.npy')
mag_wave96h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_96h.npy')

mag_wave48h[0] = 0.
mag_wave72h[0] = 0.
mag_wave96h[0] = 0.
mag_adj48h[0] = 0.
mag_adj72h[0] = 0.
mag_adj96h[0] = 0.

dte_adj48h_norm = dte_adj48h/tot_48h
dte_wave48h_norm = dte_wave48h/tot_48h
dte_adj72h_norm = dte_adj72h/tot_72h
dte_wave72h_norm = dte_wave72h/tot_72h
dte_adj96h_norm = dte_adj96h/tot_96h
dte_wave96h_norm = dte_wave96h/tot_96h

dte_adj48h_short_norm = dte_adj48h_short/np.mean(tot_48h[0:4])
dte_wave48h_short_norm = dte_wave48h_short/np.mean(tot_48h[0:4])
dte_adj72h_short_norm = dte_adj72h_short/np.mean(tot_72h[0:6])
dte_wave72h_short_norm = dte_wave72h_short/np.mean(tot_72h[0:6])
dte_adj96h_short_norm = dte_adj96h_short/np.mean(tot_96h[0:6])
dte_wave96h_short_norm = dte_wave96h_short/np.mean(tot_96h[0:6])

# %%
fig, axd = plt.subplot_mosaic([['left', 'right']],
                              constrained_layout=True, figsize=(14.0,5.5),dpi=300)

trans = mtransforms.ScaledTranslation(1/10, -1/10, fig.dpi_scale_trans)

axd['left'].plot(time_short,dte_adj48h_short_norm[::2],color='m',label='48 h',linewidth=3.0)
axd['left'].plot(time_long,dte_adj48h_norm[2:],color='m',linewidth=3.0)
axd['left'].plot(time_short,dte_wave48h_short_norm[::2],color='m',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time_long,dte_wave48h_norm[2:],color='m',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time_short,dte_adj72h_short_norm[::2],color='orange',label='72 h',linewidth=3.0)
axd['left'].plot(time_long,dte_adj72h_norm[2:],color='orange',linewidth=3.0)
axd['left'].plot(time_short,dte_wave72h_short_norm[::2],color='orange',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time_long,dte_wave72h_norm[2:],color='orange',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time_short,dte_adj96h_short_norm[::2],color='g',label='96 h',linewidth=3.0)
axd['left'].plot(time_long,dte_adj96h_norm[2:],color='g',linewidth=3.0)
axd['left'].plot(time_short,dte_wave96h_short_norm[::2],color='g',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time_long,dte_wave96h_norm[2:],color='g',linestyle='dashed',linewidth=3.0)
axd['left'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['left'].set_ylabel('Normalized DTE',labelpad=6,fontsize=20)
axd['left'].xaxis.set_major_locator(MultipleLocator(6))
axd['left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['left'].grid(linewidth=1.5)
axd['left'].text(0.0, 1.0, '(a)',transform=axd['left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['right'].plot(time,mag_adj48h,color='m',label='48 h',linewidth=3.0)
axd['right'].plot(time,mag_adj72h,color='orange',label='72 h',linewidth=3.0)
axd['right'].plot(time,mag_adj96h,color='g',label='96 h',linewidth=3.0)
axd['right'].plot(time,mag_wave48h,color='m',linestyle='dashed',linewidth=3.0)
axd['right'].plot(time,mag_wave72h,color='orange',linestyle='dashed',linewidth=3.0)
axd['right'].plot(time,mag_wave96h,color='g',linestyle='dashed',linewidth=3.0)
axd['right'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['right'].set_ylabel('Pressure Difference (hPa)',labelpad=6,fontsize=20)
axd['right'].xaxis.set_major_locator(MultipleLocator(6))
axd['right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['right'].grid(linewidth=1.5)
axd['right'].set_ylim([-9,1.5])
axd['right'].legend(prop={"size":18})
axd['right'].text(0.0, 1.0, '(b)',transform=axd['right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

#plt.savefig('/p/work1/lloveras/adj_4km/figs/new_figs/norms_later.pdf',bbox_inches='tight')

# %%
mag_adj48h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_48h.npy')
mag_adj72h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_72h.npy')
mag_adj96h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_adj_96h.npy')
mag_wave48h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_48h.npy')
mag_wave72h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_72h.npy')
mag_wave96h = np.load('/p/work1/lloveras/adj_4km/processed/slp/mag_slp_wave_96h.npy')

mag_wave48h[0] = 0.
mag_wave72h[0] = 0.
mag_wave96h[0] = 0.
mag_adj48h[0] = 0.
mag_adj72h[0] = 0.
mag_adj96h[0] = 0.

fss_adj48h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_48h.npy'))
fss_adj72h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_72h.npy'))
fss_adj96h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_adj_96h.npy'))
fss_wave48h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_48h.npy'))
fss_wave72h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_72h.npy'))
fss_wave96h = np.append(1,np.load('/p/work1/lloveras/adj_4km/processed/fss/fss_wave_96h.npy'))

# %%
fig, axd = plt.subplot_mosaic([['left', 'right']],
                              constrained_layout=True, figsize=(14.0,5.5),dpi=300)

trans = mtransforms.ScaledTranslation(1/10, -1/10, fig.dpi_scale_trans)

axd['left'].plot(time,mag_adj48h,color='m',label='48 h',linewidth=3.0)
axd['left'].plot(time,mag_adj72h,color='orange',label='72 h',linewidth=3.0)
axd['left'].plot(time,mag_adj96h,color='g',label='96 h',linewidth=3.0)
axd['left'].plot(time,mag_wave48h,color='m',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time,mag_wave72h,color='orange',linestyle='dashed',linewidth=3.0)
axd['left'].plot(time,mag_wave96h,color='g',linestyle='dashed',linewidth=3.0)
axd['left'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['left'].set_ylabel('Pressure Difference (hPa)',labelpad=6,fontsize=20)
axd['left'].xaxis.set_major_locator(MultipleLocator(6))
axd['left'].xaxis.set_minor_locator(MultipleLocator(3))
axd['left'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['left'].grid(linewidth=1.5)
axd['left'].set_ylim([-9,1.5])
axd['left'].legend(prop={"size":18})
axd['left'].text(0.0, 1.0, '(a)',transform=axd['left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

axd['right'].plot(time,fss_adj48h,color='m',label='48 h',linewidth=3.0)
axd['right'].plot(time,fss_adj72h,color='orange',label='72 h',linewidth=3.0)
axd['right'].plot(time,fss_adj96h,color='g',label='96 h',linewidth=3.0)
axd['right'].plot(time,fss_wave48h,color='m',linestyle='dashed',linewidth=3.0)
axd['right'].plot(time,fss_wave72h,color='orange',linestyle='dashed',linewidth=3.0)
axd['right'].plot(time,fss_wave96h,color='g',linestyle='dashed',linewidth=3.0)
axd['right'].set_xlabel('Lead Time (h)',labelpad=6,fontsize=20)
axd['right'].set_ylabel('FSS',labelpad=6,fontsize=20)
axd['right'].xaxis.set_major_locator(MultipleLocator(6))
axd['right'].xaxis.set_minor_locator(MultipleLocator(3))
axd['right'].tick_params(axis='both',labelsize=20,which='both',direction='in',length=4,width=1)
axd['right'].grid(linewidth=1.5)
axd['right'].set_ylim([0.12,1.12])
axd['right'].text(0.0, 1.0, '(b)',transform=axd['right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2))

plt.savefig('/p/work1/lloveras/adj_4km/meso_figs/slp_fss_later.pdf',bbox_inches='tight')
