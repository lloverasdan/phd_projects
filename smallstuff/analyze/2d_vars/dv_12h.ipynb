# %%
# %pylab inline
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import warnings
warnings.filterwarnings("ignore")
import matplotlib.transforms as mtransforms

G = 9.81
dx = 4
rol = -1000

v_ctl = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_ctl_12h.npy')
v_adj = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_adj_12h.npy')
v_wave = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_wave_12h.npy')
v_adj10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_adj10_12h.npy')
v_wave10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_wave10_12h.npy')
v_adj100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_adj100_12h.npy')
v_wave100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/v500_wave100_12h.npy')

z_ctl = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_ctl_12h.npy')
z_adj = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_adj_12h.npy')
z_wave = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_wave_12h.npy')
z_adj10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_adj10_12h.npy')
z_wave10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_wave10_12h.npy')
z_adj100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_adj100_12h.npy')
z_wave100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/z500_wave100_12h.npy')

# v_ctl = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_ctl.npy')[0]
# v_adj = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_adj.npy')[0]
# v_wave = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_wave.npy')[0]
# v_adj10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_adj10.npy')[0]
# v_wave10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_wave10.npy')[0]
# v_adj100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_adj100.npy')[0]
# v_wave100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/v350_wave100.npy')[0]

# z_ctl = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_ctl.npy')[0]
# z_adj = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_adj.npy')[0]
# z_wave = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_wave.npy')[0]
# z_adj10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_adj10.npy')[0]
# z_wave10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_wave10.npy')[0]
# z_adj100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_adj100.npy')[0]
# z_wave100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/350hpa_48h/z350_wave100.npy')[0]

dbz_ctl = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_ctl_12h.npy')
dbz_adj = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_adj_12h.npy')
dbz_wave = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_wave_12h.npy')
dbz_adj10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_adj10_12h.npy')
dbz_wave10 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_wave10_12h.npy')
dbz_adj100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_adj100_12h.npy')
dbz_wave100 = np.load('/p/work1/lloveras/adj_4km/processed/2d_fields/data_48h/mdbz_wave100_12h.npy')

# %%
x1 = 500
x2 = 801
y1 = 700
y2 = 1001

yax1 = np.arange(y1*dx,y2*dx,400).astype(int)
yax2 = (yax1 - y1*dx)/float(dx)
yax2 = yax2.astype(int)
yax1 = ["%0.0f" % number for number in yax1]
xax1 = np.arange(x1*dx,x2*dx,400).astype(int)
xax2 = (xax1 - x1*dx)/float(dx)
xax2 = xax2.astype(int)
xax1 = ["%0.0f" % number for number in xax1]

# %%
v_ctl = np.roll(v_ctl,rol,axis=-1)[y1:y2,x1:x2]
v_adj = np.roll(v_adj,rol,axis=-1)[y1:y2,x1:x2]
v_wave = np.roll(v_wave,rol,axis=-1)[y1:y2,x1:x2]
v_adj10 = np.roll(v_adj10,rol,axis=-1)[y1:y2,x1:x2]
v_wave10 = np.roll(v_wave10,rol,axis=-1)[y1:y2,x1:x2]
v_adj100 = np.roll(v_adj100,rol,axis=-1)[y1:y2,x1:x2]
v_wave100 = np.roll(v_wave100,rol,axis=-1)[y1:y2,x1:x2]

z_ctl = np.roll(z_ctl,rol,axis=-1)[y1:y2,x1:x2]
z_adj = np.roll(z_adj,rol,axis=-1)[y1:y2,x1:x2]
z_wave = np.roll(z_wave,rol,axis=-1)[y1:y2,x1:x2]
z_adj10 = np.roll(z_adj10,rol,axis=-1)[y1:y2,x1:x2]
z_wave10 = np.roll(z_wave10,rol,axis=-1)[y1:y2,x1:x2]
z_adj100 = np.roll(z_adj100,rol,axis=-1)[y1:y2,x1:x2]
z_wave100 = np.roll(z_wave100,rol,axis=-1)[y1:y2,x1:x2]

dbz_ctl = np.roll(dbz_ctl,rol,axis=-1)[y1:y2,x1:x2]
dbz_adj = np.roll(dbz_adj,rol,axis=-1)[y1:y2,x1:x2]
dbz_wave = np.roll(dbz_wave,rol,axis=-1)[y1:y2,x1:x2]
dbz_adj10 = np.roll(dbz_adj10,rol,axis=-1)[y1:y2,x1:x2]
dbz_wave10 = np.roll(dbz_wave10,rol,axis=-1)[y1:y2,x1:x2]
dbz_adj100 = np.roll(dbz_adj100,rol,axis=-1)[y1:y2,x1:x2]
dbz_wave100 = np.roll(dbz_wave100,rol,axis=-1)[y1:y2,x1:x2]

# %%
dv_adj = np.nan_to_num(v_adj - v_ctl)
dv_wave = np.nan_to_num(v_wave - v_ctl)
dv_adj10 = np.nan_to_num(v_adj10 - v_ctl)
dv_wave10 = np.nan_to_num(v_wave10 - v_ctl)
dv_adj100 = np.nan_to_num(v_adj100 - v_ctl)
dv_wave100 = np.nan_to_num(v_wave100 - v_ctl)

# %%
fig, axd = plt.subplot_mosaic([['top left','top center','top right','cbar'],
                               ['bottom left','bottom center','bottom right','cbar']],
                              constrained_layout=True, figsize=(16.5,9), 
                              gridspec_kw={'width_ratios':[1,1,1,0.1],'height_ratios':[1,1]})

trans = mtransforms.ScaledTranslation(1/25, -1/25, fig.dpi_scale_trans)

#cmap = plt.get_cmap('bwr')
# clrs=['cyan','blue','royalblue','dodgerblue','cornflowerblue','deepskyblue',\
#        'white','lightcoral','salmon','indianred','red','darkred','orange']
# clrs=['cyan','blue','royalblue','dodgerblue','deepskyblue',\
#        'white','salmon','indianred','red','darkred','orange']

clrs = ['cyan',#'#0000FF',
        '#3434FF',
        '#6666FF',
        '#9898FF',
        '#CCCCFF',
        '#FFFEFE',
        '#FFCCCC',
        '#FF9A9A',
        '#FF6666',
        '#FF3232',
        'yellow'] #'FF0000'
lvls = np.asarray([-11,-9,-7,-5,-3,-1,1,3,5,7,9,11])/2
nm = colors.BoundaryNorm(lvls,256)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("",clrs)
cmap.set_under('darkgreen')
cmap.set_over('brown')

#cs1 = axd['top left'].contour(z_adj,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['top left'].clabel(cs1,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im1 = axd['top left'].contourf(dv_adj,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['top left'].contourf(dbz_adj,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top left'].set_xticks(xax2)
axd['top left'].set_xticklabels(['','','',''])
axd['top left'].set_ylabel('South-North (km)',labelpad=6,fontsize=20)
axd['top left'].set_yticks(yax2)
axd['top left'].set_yticklabels(yax1)
axd['top left'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top left'].set_aspect('equal')
axd['top left'].set_title('Full',pad=12,fontsize=24)
axd['top left'].grid()
axd['top left'].text(-0.575, 0.625, 'Adjoint',transform=axd['top left'].transAxes + trans,
            fontsize=24, verticalalignment='top',rotation='vertical')
axd['top left'].text(0.001, 1.0, '(a)',transform=axd['top left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

#cs2 = axd['top center'].contour(z_adj10,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['top center'].clabel(cs2,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im2 = axd['top center'].contourf(dv_adj10,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['top center'].contourf(dbz_adj10,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top center'].set_xticks(xax2)
axd['top center'].set_xticklabels(['','','',''])
axd['top center'].set_yticks(yax2)
axd['top center'].set_yticklabels(['','','',''])
axd['top center'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top center'].set_aspect('equal')
axd['top center'].set_title('1/10',pad=12,fontsize=24)
axd['top center'].grid()
axd['top center'].text(0.001, 1.0, '(b)',transform=axd['top center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

#cs3 = axd['top right'].contour(z_adj100,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['top right'].clabel(cs3,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im3 = axd['top right'].contourf(dv_adj100,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['top right'].contourf(dbz_adj100,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top right'].set_xticks(xax2)
axd['top right'].set_xticklabels(['','','',''])
axd['top right'].set_yticks(yax2)
axd['top right'].set_yticklabels(['','','',''])
axd['top right'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top right'].set_aspect('equal')
axd['top right'].set_title('1/100',pad=12,fontsize=24)
axd['top right'].grid()
axd['top right'].text(0.001, 1.0, '(c)',transform=axd['top right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

#cs4 = axd['bottom left'].contour(z_wave,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['bottom left'].clabel(cs4,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im4 = axd['bottom left'].contourf(dv_wave,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['bottom left'].contourf(dbz_wave,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom left'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom left'].set_xticks(xax2)
axd['bottom left'].set_xticklabels(xax1)
axd['bottom left'].set_ylabel('South-North (km)',labelpad=6,fontsize=20)
axd['bottom left'].set_yticks(yax2)
axd['bottom left'].set_yticklabels(yax1)
axd['bottom left'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom left'].set_aspect('equal')
axd['bottom left'].grid()
axd['bottom left'].text(-0.575, 0.625, 'Wave',transform=axd['bottom left'].transAxes + trans,
            fontsize=24, verticalalignment='top',rotation='vertical')
axd['bottom left'].text(0.001, 1.0, '(d)',transform=axd['bottom left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

#cs5 = axd['bottom center'].contour(z_wave10,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['bottom center'].clabel(cs5,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im5 = axd['bottom center'].contourf(dv_wave10,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['bottom center'].contourf(dbz_wave10,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom center'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom center'].set_xticks(xax2)
axd['bottom center'].set_xticklabels(xax1)
axd['bottom center'].set_yticks(yax2)
axd['bottom center'].set_yticklabels(['','','',''])
axd['bottom center'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom center'].set_aspect('equal')
axd['bottom center'].grid()
axd['bottom center'].text(0.001, 1.0, '(e)',transform=axd['bottom center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

#cs6 = axd['bottom right'].contour(z_wave100,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
#axd['bottom right'].clabel(cs6,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im6 = axd['bottom right'].contourf(dv_wave100,levels=lvls,extend='both',cmap=cmap,norm=nm,alpha=0.9)
axd['bottom right'].contourf(dbz_wave100,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom right'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom right'].set_xticks(xax2)
axd['bottom right'].set_xticklabels(xax1)
axd['bottom right'].set_yticks(yax2)
axd['bottom right'].set_yticklabels(['','','',''])
axd['bottom right'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom right'].set_aspect('equal')
axd['bottom right'].grid()
axd['bottom right'].text(0.001, 1.0, '(f)',transform=axd['bottom right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cbar = fig.colorbar(im1, orientation="vertical", cax=axd['cbar'],ticks=lvls)
cbar.ax.tick_params(labelsize=20, pad=10)
cbar.ax.set_yticklabels(['-5.5','-4.5','-3.5','-2.5','-1.5','-0.5',\
                       '0.5','1.5','2.5','3.5','4.5','5.5']) 

plt.savefig('/p/work1/lloveras/adj_4km/figs_june/dv_12h.pdf',bbox_inches='tight')
