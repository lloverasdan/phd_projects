# %%
# %pylab inline
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from wrf import smooth2d
import warnings
warnings.filterwarnings("ignore")
import matplotlib.transforms as mtransforms

G = 9.81
dx = 4
rol = -1000

v_ctl_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_ctl_12h.npy')
v_adj_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_adj_12h.npy')
v_wave_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_wave_12h.npy')

z_ctl_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_ctl_12h.npy')
z_adj_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_adj_12h.npy')
z_wave_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_wave_12h.npy')

dbz_ctl_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_ctl_12h.npy')
dbz_adj_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_adj_12h.npy')
dbz_wave_12h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_wave_12h.npy')

v_ctl_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_ctl_30h.npy')
v_adj_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_adj_30h.npy')
v_wave_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_wave_30h.npy')

z_ctl_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_ctl_30h.npy')
z_adj_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_adj_30h.npy')
z_wave_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_wave_30h.npy')

dbz_ctl_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_ctl_30h.npy')
dbz_adj_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_adj_30h.npy')
dbz_wave_30h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_wave_30h.npy')

v_ctl_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_ctl_48h.npy')
v_adj_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_adj_48h.npy')
v_wave_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/v500_wave_48h.npy')

z_ctl_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_ctl_48h.npy')
z_adj_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_adj_48h.npy')
z_wave_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/z500_wave_48h.npy')

dbz_ctl_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_ctl_48h.npy')
dbz_adj_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_adj_48h.npy')
dbz_wave_48h = np.load('/p/work1/lloveras/adj_4km/processed_data/var_files/data_48h/mdbz_wave_48h.npy')

# %%
x1_12 = 250
x2_12 = 1001
y1_12 = 600
y2_12 = 1351

x1_30 = 450
x2_30 = 1201
y1_30 = 600
y2_30 = 1351

x1_48 = 650
x2_48 = 1401
y1_48 = 600
y2_48 = 1351

yax1_12 = np.arange(y1_12*dx,y2_12*dx,1000).astype(int)
yax2_12 = (yax1_12 - y1_12*dx)/float(dx)
yax2_12 = yax2_12.astype(int)
yax1_12 = ["%0.0f" % number for number in yax1_12]
xax1_12 = np.arange(x1_12*dx,x2_12*dx,1000).astype(int)
xax2_12 = (xax1_12 - x1_12*dx)/float(dx)
xax2_12 = xax2_12.astype(int)
xax1_12 = ["%0.0f" % number for number in xax1_12]

yax1_30 = np.arange(y1_30*dx,y2_30*dx,1000).astype(int)
yax2_30 = (yax1_30 - y1_30*dx)/float(dx)
yax2_30 = yax2_30.astype(int)
yax1_30 = ["%0.0f" % number for number in yax1_30]
xax1_30 = np.arange(x1_30*dx,x2_30*dx,1000).astype(int)
xax2_30 = (xax1_30 - x1_30*dx)/float(dx)
xax2_30 = xax2_30.astype(int)
xax1_30 = ["%0.0f" % number for number in xax1_30]

yax1_48 = np.arange(y1_48*dx,y2_48*dx,1000).astype(int)
yax2_48 = (yax1_48 - y1_48*dx)/float(dx)
yax2_48 = yax2_48.astype(int)
yax1_48 = ["%0.0f" % number for number in yax1_48]
xax1_48 = np.arange(x1_48*dx,x2_48*dx,1000).astype(int)
xax2_48 = (xax1_48 - x1_48*dx)/float(dx)
xax2_48 = xax2_48.astype(int)
xax1_48 = ["%0.0f" % number for number in xax1_48]

# %%
v_ctl_12h = np.roll(v_ctl_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
v_adj_12h = np.roll(v_adj_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
v_wave_12h = np.roll(v_wave_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
v_ctl_30h = np.roll(v_ctl_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
v_adj_30h = np.roll(v_adj_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
v_wave_30h = np.roll(v_wave_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
v_ctl_48h = np.roll(v_ctl_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
v_adj_48h = np.roll(v_adj_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
v_wave_48h = np.roll(v_wave_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]

dbz_ctl_12h = np.roll(dbz_ctl_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
dbz_adj_12h = np.roll(dbz_adj_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
dbz_wave_12h = np.roll(dbz_wave_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
dbz_ctl_30h = np.roll(dbz_ctl_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
dbz_adj_30h = np.roll(dbz_adj_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
dbz_wave_30h = np.roll(dbz_wave_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
dbz_ctl_48h = np.roll(dbz_ctl_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
dbz_adj_48h = np.roll(dbz_adj_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
dbz_wave_48h = np.roll(dbz_wave_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]

z_ctl_12h = np.roll(z_ctl_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
z_adj_12h = np.roll(z_adj_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
z_wave_12h = np.roll(z_wave_12h,rol,axis=-1)[y1_12:y2_12,x1_12:x2_12]
z_ctl_30h = np.roll(z_ctl_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
z_adj_30h = np.roll(z_adj_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
z_wave_30h = np.roll(z_wave_30h,rol,axis=-1)[y1_30:y2_30,x1_30:x2_30]
z_ctl_48h = np.roll(z_ctl_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
z_adj_48h = np.roll(z_adj_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]
z_wave_48h = np.roll(z_wave_48h,rol,axis=-1)[y1_48:y2_48,x1_48:x2_48]

# %%
dv_adj_12h = np.nan_to_num(v_adj_12h - v_ctl_12h)
dv_wave_12h = np.nan_to_num(v_wave_12h - v_ctl_12h)
dv_adj_30h = np.nan_to_num(v_adj_30h - v_ctl_30h)
dv_wave_30h = np.nan_to_num(v_wave_30h - v_ctl_30h)
dv_adj_48h = np.nan_to_num(v_adj_48h - v_ctl_48h)
dv_wave_48h = np.nan_to_num(v_wave_48h - v_ctl_48h)

dbz_ctl_12h = smooth2d(dbz_ctl_12h,5)
dbz_adj_12h = smooth2d(dbz_adj_12h,5)
dbz_wave_12h = smooth2d(dbz_wave_12h,5)
dbz_ctl_30h = smooth2d(dbz_ctl_30h,5)
dbz_adj_30h = smooth2d(dbz_adj_30h,5)
dbz_wave_30h = smooth2d(dbz_wave_30h,5)
dbz_ctl_48h = smooth2d(dbz_ctl_48h,5)
dbz_adj_48h = smooth2d(dbz_adj_48h,5)
dbz_wave_48h = smooth2d(dbz_wave_48h,5)

# %%
fig, axd = plt.subplot_mosaic([['top left','top center','top right','cbar'],
                               ['bottom left','bottom center','bottom right','cbar']],
                              constrained_layout=True, figsize=(16.5,9), 
                              gridspec_kw={'width_ratios':[1,1,1,0.1],'height_ratios':[1,1]})

lvls = np.asarray([-9,-7,-5,-3,-1,1,3,5,7,9])
lvls2 = lvls
nm = colors.BoundaryNorm(lvls,256)
trans = mtransforms.ScaledTranslation(1/25, -1/25, fig.dpi_scale_trans)

cmap = plt.get_cmap('bwr')
cmap.set_under('navy')
cmap.set_over('brown')

cs1 = axd['top left'].contour(z_adj_12h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['top left'].clabel(cs1,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im1 = axd['top left'].contourf(dv_adj_12h,levels=lvls,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['top left'].contourf(dbz_adj_12h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top left'].set_xticks(xax2_12)
axd['top left'].set_xticklabels(['','','',''])
axd['top left'].set_ylabel('South-North (km)',labelpad=6,fontsize=20)
axd['top left'].set_yticks(yax2_12)
axd['top left'].set_yticklabels(yax1_12)
axd['top left'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top left'].set_aspect('equal')
axd['top left'].set_title('12 h',pad=12,fontsize=24)
axd['top left'].grid()
axd['top left'].text(-0.575, 0.625, 'Adjoint',transform=axd['top left'].transAxes + trans,
            fontsize=24, verticalalignment='top',rotation='vertical')
axd['top left'].text(0.001, 1.0, '(a)',transform=axd['top left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cs2 = axd['top center'].contour(z_adj_30h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['top center'].clabel(cs2,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im2 = axd['top center'].contourf(dv_adj_30h,levels=lvls,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['top center'].contourf(dbz_adj_30h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top center'].set_xticks(xax2_30)
axd['top center'].set_xticklabels(['','','',''])
axd['top center'].set_yticks(yax2_30)
axd['top center'].set_yticklabels(['','','',''])
axd['top center'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top center'].set_aspect('equal')
axd['top center'].set_title('30 h',pad=12,fontsize=24)
axd['top center'].grid()
axd['top center'].text(0.001, 1.0, '(b)',transform=axd['top center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cs3 = axd['top right'].contour(z_adj_48h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['top right'].clabel(cs3,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im3 = axd['top right'].contourf(dv_adj_48h,levels=lvls,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['top right'].contourf(dbz_adj_48h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['top right'].set_xticks(xax2_48)
axd['top right'].set_xticklabels(['','','',''])
axd['top right'].set_yticks(yax2_48)
axd['top right'].set_yticklabels(['','','',''])
axd['top right'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['top right'].set_aspect('equal')
axd['top right'].set_title('48 h',pad=12,fontsize=24)
axd['top right'].grid()
axd['top right'].text(0.001, 1.0, '(c)',transform=axd['top right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cs4 = axd['bottom left'].contour(z_wave_12h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['bottom left'].clabel(cs4,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im4 = axd['bottom left'].contourf(dv_wave_12h,levels=lvls2,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['bottom left'].contourf(dbz_wave_12h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom left'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom left'].set_xticks(xax2_12)
axd['bottom left'].set_xticklabels(xax1_12)
axd['bottom left'].set_ylabel('South-North (km)',labelpad=6,fontsize=20)
axd['bottom left'].set_yticks(yax2_12)
axd['bottom left'].set_yticklabels(yax1_12)
axd['bottom left'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom left'].set_aspect('equal')
axd['bottom left'].grid()
axd['bottom left'].text(-0.575, 0.625, 'Wave',transform=axd['bottom left'].transAxes + trans,
            fontsize=24, verticalalignment='top',rotation='vertical')
axd['bottom left'].text(0.001, 1.0, '(d)',transform=axd['bottom left'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cs5 = axd['bottom center'].contour(z_wave_30h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['bottom center'].clabel(cs5,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im5 = axd['bottom center'].contourf(dv_wave_30h,levels=lvls2,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['bottom center'].contourf(dbz_wave_30h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom center'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom center'].set_xticks(xax2_30)
axd['bottom center'].set_xticklabels(xax1_30)
axd['bottom center'].set_yticks(yax2_30)
axd['bottom center'].set_yticklabels(['','','',''])
axd['bottom center'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom center'].set_aspect('equal')
axd['bottom center'].grid()
axd['bottom center'].text(0.001, 1.0, '(e)',transform=axd['bottom center'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cs6 = axd['bottom right'].contour(z_wave_48h,colors='k',levels=np.arange(0,1000,10),linewidths=2,alpha=0.75)
axd['bottom right'].clabel(cs6,fmt='%1.0f',inline=1,levels=np.arange(0,1000,10),fontsize=10,colors='k')
im6 = axd['bottom right'].contourf(dv_wave_48h,levels=lvls2,extend='both',cmap=cmap,alpha=0.9,norm=nm)
axd['bottom right'].contourf(dbz_wave_48h,levels=[0,0.01],colors='k',extend='max',alpha=0.25)
axd['bottom right'].set_xlabel('West-East (km)',labelpad=6,fontsize=20)
axd['bottom right'].set_xticks(xax2_48)
axd['bottom right'].set_xticklabels(xax1_48)
axd['bottom right'].set_yticks(yax2_12)
axd['bottom right'].set_yticklabels(['','','',''])
axd['bottom right'].tick_params(axis='both', labelsize=20, which='major', pad=8,length=8)
axd['bottom right'].set_aspect('equal')
axd['bottom right'].grid()
axd['bottom right'].text(0.001, 1.0, '(f)',transform=axd['bottom right'].transAxes + trans,
            fontsize=20, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='none', pad=2),zorder=10)

cbar = fig.colorbar(im1, orientation="vertical", cax=axd['cbar'])
cbar.ax.tick_params(labelsize=20, pad=10)

#plt.savefig('/p/work1/lloveras/adj_4km/revised_figs/dv500.pdf',bbox_inches='tight')
